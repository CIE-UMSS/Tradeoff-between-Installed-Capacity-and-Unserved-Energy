# %%
import pandas as pd
Jan=pd.read_csv('Jan_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Feb=pd.read_csv('Feb_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Mar=pd.read_csv('Mar_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Apr=pd.read_csv('Apr_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
May=pd.read_csv('May_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jun=pd.read_csv('Jun_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jul=pd.read_csv('Jul_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Aug=pd.read_csv('Aug_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Sep=pd.read_csv('Sep_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Oct=pd.read_csv('Oct_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Nov=pd.read_csv('Nov_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Dec=pd.read_csv('Dec_BSA_o.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jan['0'] = Jan['0'].astype(float)
Jan['Unnamed: 0'] = Jan['Unnamed: 0'].astype(float)
Feb['0'] = Feb['0'].astype(float)
Feb['Unnamed: 0'] = Feb['Unnamed: 0'].astype(float)
Mar['0'] = Mar['0'].astype(float)
Mar['Unnamed: 0'] = Mar['Unnamed: 0'].astype(float)
Apr['0'] = Apr['0'].astype(float)
Apr['Unnamed: 0'] = Apr['Unnamed: 0'].astype(float)
May['0'] = May['0'].astype(float)
May['Unnamed: 0'] = May['Unnamed: 0'].astype(float)
Jun['0'] = Jun['0'].astype(float)
Jun['Unnamed: 0'] = Jun['Unnamed: 0'].astype(float)
Jul['0'] = Jul['0'].astype(float)
Jul['Unnamed: 0'] = Jul['Unnamed: 0'].astype(float)
Aug['0'] = Aug['0'].astype(float)
Aug['Unnamed: 0'] = Aug['Unnamed: 0'].astype(float)
Sep['0'] = Sep['0'].astype(float)
Sep['Unnamed: 0'] = Sep['Unnamed: 0'].astype(float)
Oct['0'] = Oct['0'].astype(float)
Oct['Unnamed: 0'] = Oct['Unnamed: 0'].astype(float)
Nov['0'] = Nov['0'].astype(float)
Nov['Unnamed: 0'] = Nov['Unnamed: 0'].astype(float) 
Dec['0'] = Dec['0'].astype(float)

# %%
Jan_1=pd.read_csv('Jan_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Feb_1=pd.read_csv('Feb_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Mar_1=pd.read_csv('Mar_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Apr_1=pd.read_csv('Apr_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
May_1=pd.read_csv('May_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jun_1=pd.read_csv('Jun_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jul_1=pd.read_csv('Jul_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Aug_1=pd.read_csv('Aug_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Sep_1=pd.read_csv('Sep_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Oct_1=pd.read_csv('Oct_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Nov_1=pd.read_csv('Nov_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Dec_1=pd.read_csv('Dec_BSA_t.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jan_1['0'] = Jan_1['0'].astype(float)
Jan['Unnamed: 0'] = Jan['Unnamed: 0'].astype(float)
Feb_1['0'] = Feb_1['0'].astype(float)
Feb['Unnamed: 0'] = Feb['Unnamed: 0'].astype(float)
Mar_1['0'] = Mar_1['0'].astype(float)
Mar['Unnamed: 0'] = Mar['Unnamed: 0'].astype(float)
Apr_1['0'] = Apr_1['0'].astype(float)
Apr['Unnamed: 0'] = Apr['Unnamed: 0'].astype(float)
May_1['0'] = May_1['0'].astype(float)
May['Unnamed: 0'] = May['Unnamed: 0'].astype(float)
Jun_1['0'] = Jun_1['0'].astype(float)
Jun['Unnamed: 0'] = Jun['Unnamed: 0'].astype(float)
Jul_1['0'] = Jul_1['0'].astype(float)
Jul['Unnamed: 0'] = Jul['Unnamed: 0'].astype(float)
Aug_1['0'] = Aug_1['0'].astype(float)
Aug['Unnamed: 0'] = Aug['Unnamed: 0'].astype(float)
Sep_1['0'] = Sep_1['0'].astype(float)
Sep['Unnamed: 0'] = Sep['Unnamed: 0'].astype(float)
Oct_1['0'] = Oct_1['0'].astype(float)
Oct['Unnamed: 0'] = Oct['Unnamed: 0'].astype(float)
Nov_1['0'] = Nov_1['0'].astype(float)
Nov['Unnamed: 0'] = Nov['Unnamed: 0'].astype(float) 
Dec_1['0'] = Dec_1['0'].astype(float)

# %%
import numpy as np
Jan['time_series']=np.arange(0,len(Jan),1)
Jan['time_series']=Jan['time_series']/60
Feb['time_series']=np.arange(0,len(Feb),1)
Feb['time_series']=Feb['time_series']/60
Mar['time_series']=np.arange(0,len(Mar),1)
Mar['time_series']=Mar['time_series']/60
Apr['time_series']=np.arange(0,len(Apr),1)
Apr['time_series']=Apr['time_series']/60
May['time_series']=np.arange(0,len(May),1)
May['time_series']=May['time_series']/60
Jun['time_series']=np.arange(0,len(Jun),1)
Jun['time_series']=Jun['time_series']/60
Jul['time_series']=np.arange(0,len(Jul),1)
Jul['time_series']=Jul['time_series']/60
Aug['time_series']=np.arange(0,len(Aug),1)
Aug['time_series']=Aug['time_series']/60
Sep['time_series']=np.arange(0,len(Sep),1)
Sep['time_series']=Sep['time_series']/60
Oct['time_series']=np.arange(0,len(Oct),1)
Oct['time_series']=Oct['time_series']/60
Nov['time_series']=np.arange(0,len(Nov),1)
Nov['time_series']=Nov['time_series']/60
Dec['time_series']=np.arange(0,len(Dec),1)
Dec['time_series']=Dec['time_series']/60

# %%
import matplotlib.pyplot as plt 
fig, axs = plt.subplots(3, 4)
axs[0, 0].plot(Jan['time_series'], Jan['0'],color='blue',linewidth=1)
axs[0, 0].set_title('January')
#axs[0, 0].set_yticks([0, 5, 10, 15, 20, 25])
axs[0, 1].plot(Feb['time_series'], Feb['0'],color='blue',linewidth=1)
axs[0, 1].set_title('February')
axs[0, 2].plot(Mar['time_series'], Mar['0'],color='blue',linewidth=1)
axs[0, 2].set_title('March')
axs[0, 3].plot(Apr['time_series'], Apr['0'],color='blue',linewidth=1)
axs[0, 3].set_title('April')
axs[1, 0].plot(May['time_series'], May['0'],color='blue',linewidth=1)
axs[1, 0].set_title('May')
#axs[1, 0].set_yticks([0, 5, 10, 15, 20, 25])
axs[1, 1].plot(Jun['time_series'], Jun['0'],color='blue',linewidth=1)
axs[1, 1].set_title('June')
axs[1, 2].plot(Jul['time_series'], Jul['0'],color='blue',linewidth=1)
axs[1, 2].set_title('July')
axs[1, 3].plot(Aug['time_series'], Aug['0'],color='blue',linewidth=1)
axs[1, 3].set_title('August')
axs[2, 0].plot(Sep['time_series'], Sep['0'],color='blue',linewidth=1)
axs[2, 0].set_title('September')
#axs[2, 0].set_yticks([0, 5, 10, 15, 20, 25])
axs[2, 0].set_xticks([0, 10, 20])
axs[2, 1].plot(Oct['time_series'], Oct['0'],color='blue',linewidth=1)
axs[2, 1].set_title('October')
axs[2, 1].set_xticks([0, 10, 20])
axs[2, 2].plot(Nov['time_series'], Nov['0'],color='blue',linewidth=1)
axs[2, 2].set_title('November')
axs[2, 2].set_xticks([0, 10, 20])
axs[2, 3].plot(Dec['time_series'], Dec['0'],color='blue',linewidth=1)
axs[2, 3].set_title('December')
axs[2, 3].set_xticks([0, 10, 20])
for ax in axs.flat:
    ax.set(xlabel='Local time (h)', ylabel='0 (W)')
#Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
plt.subplots_adjust(bottom=0.1, right=1.7, top=1.5)
plt.figure(figsize=(25,50))
plt.tight_layout(pad=0.4, w_pad=1, h_pad=1.0)
#plt.savefig('profiles_temp_raq_2018.png', dpi=200,bbox_inches="tight")
fig.savefig('demand_profiles_raq_bs.png',dpi=600,bbox_inches="tight")
plt.show()
