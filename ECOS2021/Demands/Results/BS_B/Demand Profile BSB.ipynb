# %%
import pandas as pd
import numpy as np
Jan=pd.read_csv('Jan_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Feb=pd.read_csv('Feb_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Mar=pd.read_csv('Mar_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Apr=pd.read_csv('Apr_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
May=pd.read_csv('May_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jun=pd.read_csv('Jun_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jul=pd.read_csv('Jul_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Aug=pd.read_csv('Aug_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Sep=pd.read_csv('Sep_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Oct=pd.read_csv('Oct_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Nov=pd.read_csv('Nov_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Dec=pd.read_csv('Dec_BS_B.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jan['0'] = Jan['0'].astype(float)
Jan['Unnamed: 0'] = Jan['Unnamed: 0'].astype(float)
Feb['0'] = Feb['0'].astype(float)
Feb['Unnamed: 0'] = Feb['Unnamed: 0'].astype(float)
Mar['0'] = Mar['0'].astype(float)
Mar['Unnamed: 0'] = Mar['Unnamed: 0'].astype(float)
Apr['0'] = Apr['0'].astype(float)
Apr['Unnamed: 0'] = Apr['Unnamed: 0'].astype(float)
May['0'] = May['0'].astype(float)
May['Unnamed: 0'] = May['Unnamed: 0'].astype(float)
Jun['0'] = Jun['0'].astype(float)
Jun['Unnamed: 0'] = Jun['Unnamed: 0'].astype(float)
Jul['0'] = Jul['0'].astype(float)
Jul['Unnamed: 0'] = Jul['Unnamed: 0'].astype(float)
Aug['0'] = Aug['0'].astype(float)
Aug['Unnamed: 0'] = Aug['Unnamed: 0'].astype(float)
Sep['0'] = Sep['0'].astype(float)
Sep['Unnamed: 0'] = Sep['Unnamed: 0'].astype(float)
Oct['0'] = Oct['0'].astype(float)
Oct['Unnamed: 0'] = Oct['Unnamed: 0'].astype(float)
Nov['0'] = Nov['0'].astype(float)
Nov['Unnamed: 0'] = Nov['Unnamed: 0'].astype(float) 
Dec['0'] = Dec['0'].astype(float)
Dec['Unnamed: 0'] = Dec['Unnamed: 0'].astype(float)

Jan['time']=pd.date_range(start='1/1/2018', end='2/1/2018', freq='1min', closed='left')
Jan['time'] = Jan['time'].astype('str') 
Jan[['local_date','local_time']] = Jan.time.str.split(" ",expand=True,)
Jan_mean=Jan.groupby(Jan.local_time).mean()
del Jan_mean['Unnamed: 0']
Jan_mean['time_series']=np.arange(0,len(Jan_mean),1)
Jan_mean=Jan_mean.rename(columns={'0':'power'})
Jan_mean['power']=Jan_mean['power']
Jan_mean['time_series']=Jan_mean['time_series']/60

# %%
Feb['time']=pd.date_range(start='2/1/2018', end='3/1/2018', freq='1min', closed='left')
Feb['time'] = Feb['time'].astype('str') 
Feb[['local_date','local_time']] = Feb.time.str.split(" ",expand=True,)
Feb_mean=Feb.groupby(Feb.local_time).mean()
del Feb_mean['Unnamed: 0']
Feb_mean['time_series']=np.arange(0,len(Feb_mean),1)
Feb_mean=Feb_mean.rename(columns={'0':'power'})
Feb_mean['power']=Feb_mean['power']
Feb_mean['time_series']=Feb_mean['time_series']/60

Mar['time']=pd.date_range(start='3/1/2018', end='4/1/2018', freq='1min', closed='left')
Mar['time'] = Mar['time'].astype('str') 
Mar[['local_date','local_time']] = Mar.time.str.split(" ",expand=True,)
Mar_mean=Mar.groupby(Mar.local_time).mean()
del Mar_mean['Unnamed: 0']
Mar_mean['time_series']=np.arange(0,len(Mar_mean),1)
Mar_mean=Mar_mean.rename(columns={'0':'power'})
Mar_mean['power']=Mar_mean['power']
Mar_mean['time_series']=Mar_mean['time_series']/60

Apr['time']=pd.date_range(start='4/1/2018', end='5/1/2018', freq='1min', closed='left')
Apr['time'] = Apr['time'].astype('str') 
Apr[['local_date','local_time']] = Apr.time.str.split(" ",expand=True,)
Apr_mean=Apr.groupby(Apr.local_time).mean()
del Apr_mean['Unnamed: 0']
Apr_mean['time_series']=np.arange(0,len(Apr_mean),1)
Apr_mean=Apr_mean.rename(columns={'0':'power'})
Apr_mean['power']=Apr_mean['power']
Apr_mean['time_series']=Apr_mean['time_series']/60

May['time']=pd.date_range(start='5/1/2018', end='6/1/2018', freq='1min', closed='left')
May['time'] = May['time'].astype('str') 
May[['local_date','local_time']] = May.time.str.split(" ",expand=True,)
May_mean=May.groupby(May.local_time).mean()
del May_mean['Unnamed: 0']
May_mean['time_series']=np.arange(0,len(May_mean),1)
May_mean=May_mean.rename(columns={'0':'power'})
May_mean['power']=May_mean['power']
May_mean['time_series']=May_mean['time_series']/60

Jun['time']=pd.date_range(start='6/1/2018', end='7/1/2018', freq='1min', closed='left')
Jun['time'] = Jun['time'].astype('str') 
Jun[['local_date','local_time']] = Jun.time.str.split(" ",expand=True,)
Jun_mean=Jun.groupby(Jun.local_time).mean()
del Jun_mean['Unnamed: 0']
Jun_mean['time_series']=np.arange(0,len(Jun_mean),1)
Jun_mean=Jun_mean.rename(columns={'0':'power'})
Jun_mean['power']=Jun_mean['power']
Jun_mean['time_series']=Jun_mean['time_series']/60

Jul['time']=pd.date_range(start='7/1/2018', end='8/1/2018', freq='1min', closed='left')
Jul['time'] = Jul['time'].astype('str') 
Jul[['local_date','local_time']] = Jul.time.str.split(" ",expand=True,)
Jul_mean=Jul.groupby(Jul.local_time).mean()
del Jul_mean['Unnamed: 0']
Jul_mean['time_series']=np.arange(0,len(Jul_mean),1)
Jul_mean=Jul_mean.rename(columns={'0':'power'})
Jul_mean['power']=Jul_mean['power']
Jul_mean['time_series']=Jul_mean['time_series']/60

Aug['time']=pd.date_range(start='8/1/2018', end='9/1/2018', freq='1min', closed='left')
Aug['time'] = Aug['time'].astype('str') 
Aug[['local_date','local_time']] = Aug.time.str.split(" ",expand=True,)
Aug_mean=Aug.groupby(Aug.local_time).mean()
del Aug_mean['Unnamed: 0']
Aug_mean['time_series']=np.arange(0,len(Aug_mean),1)
Aug_mean=Aug_mean.rename(columns={'0':'power'})
Aug_mean['power']=Aug_mean['power']
Aug_mean['time_series']=Aug_mean['time_series']/60

Sep['time']=pd.date_range(start='9/1/2018', end='10/1/2018', freq='1min', closed='left')
Sep['time'] = Sep['time'].astype('str') 
Sep[['local_date','local_time']] = Sep.time.str.split(" ",expand=True,)
Sep_mean=Sep.groupby(Sep.local_time).mean()
del Sep_mean['Unnamed: 0']
Sep_mean['time_series']=np.arange(0,len(Sep_mean),1)
Sep_mean=Sep_mean.rename(columns={'0':'power'})
Sep_mean['power']=Sep_mean['power']
Sep_mean['time_series']=Sep_mean['time_series']/60

Oct['time']=pd.date_range(start='10/1/2018', end='11/1/2018', freq='1min', closed='left')
Oct['time'] = Oct['time'].astype('str') 
Oct[['local_date','local_time']] = Oct.time.str.split(" ",expand=True,)
Oct_mean=Oct.groupby(Oct.local_time).mean()
del Oct_mean['Unnamed: 0']
Oct_mean['time_series']=np.arange(0,len(Oct_mean),1)
Oct_mean=Oct_mean.rename(columns={'0':'power'})
Oct_mean['power']=Oct_mean['power']
Oct_mean['time_series']=Oct_mean['time_series']/60

Nov['time']=pd.date_range(start='11/1/2018', end='12/1/2018', freq='1min', closed='left')
Nov['time'] = Nov['time'].astype('str') 
Nov[['local_date','local_time']] = Nov.time.str.split(" ",expand=True,)
Nov_mean=Nov.groupby(Nov.local_time).mean()
del Nov_mean['Unnamed: 0']
Nov_mean['time_series']=np.arange(0,len(Nov_mean),1)
Nov_mean=Nov_mean.rename(columns={'0':'power'})
Nov_mean['power']=Nov_mean['power']
Nov_mean['time_series']=Nov_mean['time_series']/60

Dec['time']=pd.date_range(start='12/1/2018', end='1/1/2019', freq='1min', closed='left')
Dec['time'] = Dec['time'].astype('str') 
Dec[['local_date','local_time']] = Dec.time.str.split(" ",expand=True,)
Dec_mean=Dec.groupby(Dec.local_time).mean()
del Dec_mean['Unnamed: 0']
Dec_mean['time_series']=np.arange(0,len(Dec_mean),1)
Dec_mean=Dec_mean.rename(columns={'0':'power'})
Dec_mean['power']=Dec_mean['power']
Dec_mean['time_series']=Dec_mean['time_series']/60

# %%
import matplotlib.pyplot as plt 
fig, axs = plt.subplots(3, 4)
axs[0, 0].plot(Jan_mean['time_series'], Jan_mean['power'],color='blue',linewidth=1)
axs[0, 0].set_title('January')
#axs[0, 0].set_yticks([0, 5, 10, 15, 20, 25])
axs[0, 1].plot(Feb_mean['time_series'], Feb_mean['power'],color='blue',linewidth=1)
axs[0, 1].set_title('February')
axs[0, 2].plot(Mar_mean['time_series'], Mar_mean['power'],color='blue',linewidth=1)
axs[0, 2].set_title('March')
axs[0, 3].plot(Apr_mean['time_series'], Apr_mean['power'],color='blue',linewidth=1)
axs[0, 3].set_title('April')
axs[1, 0].plot(May_mean['time_series'], May_mean['power'],color='blue',linewidth=1)
axs[1, 0].set_title('May')
#axs[1, 0].set_yticks([0, 5, 10, 15, 20, 25])
axs[1, 1].plot(Jun_mean['time_series'], Jun_mean['power'],color='blue',linewidth=1)
axs[1, 1].set_title('June')
axs[1, 2].plot(Jul_mean['time_series'], Jul_mean['power'],color='blue',linewidth=1)
axs[1, 2].set_title('July')
axs[1, 3].plot(Aug_mean['time_series'], Aug_mean['power'],color='blue',linewidth=1)
axs[1, 3].set_title('August')
axs[2, 0].plot(Sep_mean['time_series'], Sep_mean['power'],color='blue',linewidth=1)
axs[2, 0].set_title('September')
#axs[2, 0].set_yticks([0, 5, 10, 15, 20, 25])
axs[2, 0].set_xticks([0, 10, 20])
axs[2, 1].plot(Oct_mean['time_series'], Oct_mean['power'],color='blue',linewidth=1)
axs[2, 1].set_title('October')
axs[2, 1].set_xticks([0, 10, 20])
axs[2, 2].plot(Nov_mean['time_series'], Nov_mean['power'],color='blue',linewidth=1)
axs[2, 2].set_title('November')
axs[2, 2].set_xticks([0, 10, 20])
axs[2, 3].plot(Dec_mean['time_series'], Dec_mean['power'],color='blue',linewidth=1)
axs[2, 3].set_title('December')
axs[2, 3].set_xticks([0, 10, 20])
for ax in axs.flat:
    ax.set(xlabel='Local time (h)', ylabel='Power (W)')
#Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()
plt.subplots_adjust(bottom=0.1, right=1.7, top=1.5)
plt.figure(figsize=(25,50))
plt.tight_layout(pad=0.4, w_pad=1, h_pad=1.0)
#plt.savefig('profiles_temp_raq_2018.png', dpi=200,bbox_inches="tight")
fig.savefig('demand_profiles_raq_bs.png',dpi=600,bbox_inches="tight")
plt.show()
