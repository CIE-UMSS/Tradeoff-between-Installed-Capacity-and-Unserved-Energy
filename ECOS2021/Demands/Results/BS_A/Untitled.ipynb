# %%
import pandas as pd
import numpy as np

Jan=pd.read_csv('Jan_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Feb=pd.read_csv('Feb_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Mar=pd.read_csv('Mar_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Apr=pd.read_csv('Apr_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
May=pd.read_csv('May_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jun=pd.read_csv('Jun_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Jul=pd.read_csv('Jul_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Aug=pd.read_csv('Aug_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Sep=pd.read_csv('Sep_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Oct=pd.read_csv('Oct_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Nov=pd.read_csv('Nov_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
Dec=pd.read_csv('Dec_BS_A.csv', sep=',', decimal=',', encoding='latin1', error_bad_lines=False)
p=pd.concat([Jan, Feb, Mar, Apr, May, Jun, Jul, Aug, Sep, Oct, Nov, Dec],ignore_index=True)

del p['Unnamed: 0']
p.to_csv('minutely_BS_A.csv')

# %%
p
# Out:
#                         0
# 0                   0.002
# 1                   0.002
# 2                   0.002
# 3                   0.002
# 4                   0.002
# 5                   0.002
# 6                   0.002
# 7                   0.002
# 8                   0.002
# 9                   0.002
# 10                  0.002
# 11                  0.002
# 12                  0.002
# 13                  0.002
# 14                  0.002
# 15                  0.002
# 16                  0.002
# 17                  0.002
# 18                  0.002
# 19                  0.002
# 20                  0.002
# 21                  0.002
# 22                  0.002
# 23                  0.002
# 24                  0.002
# 25                  0.002
# 26                  0.002
# 27                  0.002
# 28                  0.002
# 29                  0.002
# ...                   ...
# 525570  73.00300000000001
# 525571  73.00300000000001
# 525572  73.00300000000001
# ...

# %%
p['min'] = np.arange(len(p))
p_split = np.array_split(p, 8760)

# %%
len(p_split)
# Out:
# 8760

# %%
# Python program to demonstrate working 
# of len() 
a = [] 
a.append("Hello") 
a.append("Geeks") 
a.append("For") 
a.append("Geeks") 
print("The length of list is: ", len(a))
# Out:
# The length of list is:  4

# %%
a
# Out:
# ['Hello', 'Geeks', 'For', 'Geeks']

# %%
p_split
# Out:
# [        0  min
#  0   0.002    0
#  1   0.002    1
#  2   0.002    2
#  3   0.002    3
#  4   0.002    4
#  5   0.002    5
#  6   0.002    6
#  7   0.002    7
#  8   0.002    8
#  9   0.002    9
#  10  0.002   10
#  11  0.002   11
#  12  0.002   12
#  13  0.002   13
#  14  0.002   14
#  15  0.002   15
#  16  0.002   16
#  17  0.002   17
#  18  0.002   18
#  19  0.002   19
#  20  0.002   20
#  21  0.002   21
#  22  0.002   22
#  23  0.002   23
#  24  0.002   24
#  25  0.002   25
#  26  0.002   26
#  27  0.002   27
#  28  0.002   28
#  29  0.002   29
#  30  0.002   30
#  31  0.002   31
#  32  0.002   32
#  33  0.002   33
#  34  0.002   34
#  35  0.002   35
#  36  0.002   36
#  37  0.002   37
#  38  0.002   38
#  39  0.002   39
#  40  0.002   40
#  41  0.002   41
#  42  0.002   42
#  43  0.002   43
#  44  0.002   44
#  45  0.002   45
#  46  0.002   46
#  47  0.002   47
#  48  0.002   48
#  49  0.002   49
#  50  0.002   50
#  51  0.002   51
#  52  0.002   52
#  53  0.002   53
# ...

# %%
for i in range (0,8760,1):
    p_split[i]['0'] = p_split[i]['0'].astype(float)
    globals()['string%s' % i]=p_split[i]['0'].mean()
e = []
for i in range (0,8760,1):
    e.append({'power_hourly': globals()['string%s' % i]})
pd.DataFrame(e)
df = pd.DataFrame(np.array([e]).T)
df.columns =['power']
df['power'] = df['power'].astype(str)
df[['gar','power']] = df.power.str.split(":",expand=True,)
df['power'] = df['power'].str.replace(r'}', '')
df['power'] = df['power'].astype(float)
df=df.rename(columns={'power': '1'})
df.index = np.arange(1, len(df)+1)
del df['gar']
df.to_csv('hourly_BS_A.csv')
df

# %%
p.loc[300]
# Out:
# 0      60.001999999999995
# min                   300
# Name: 300, dtype: object

# %%
p_split[4]['0']=p_split[4]['0'].astype(float)

# %%
p_split[4]['0'].mean()
# Out:
# 13.002516666666663

# %%
p_split[0]['0']=p_split[0]['0'].astype(float)
p_split[0]['0'].mean()
# Out:
# 0.0020000000000000013

# %%
p_split[8759]
# Out:
#                         0     min
# 525540  73.00300000000001  525540
# 525541  73.00300000000001  525541
# 525542  73.00300000000001  525542
# 525543  73.00300000000001  525543
# 525544  73.00300000000001  525544
# 525545  73.00300000000001  525545
# 525546  73.00300000000001  525546
# 525547  73.00300000000001  525547
# 525548  73.00300000000001  525548
# 525549  73.00300000000001  525549
# 525550  87.00200000000001  525550
# 525551  87.00200000000001  525551
# 525552  87.00200000000001  525552
# 525553  87.00200000000001  525553
# 525554  87.00200000000001  525554
# 525555  87.00200000000001  525555
# 525556  87.00200000000001  525556
# 525557  87.00200000000001  525557
# 525558  87.00200000000001  525558
# 525559  87.00200000000001  525559
# 525560  87.00200000000001  525560
# 525561  87.00200000000001  525561
# 525562  87.00200000000001  525562
# 525563  73.00300000000001  525563
# 525564  73.00300000000001  525564
# 525565  73.00300000000001  525565
# ...

# %%
p_split[4]B:302
# Out:
#           0  min
# 240   0.002  240
# 241   0.002  241
# 242   0.002  242
# 243   0.002  243
# 244   0.002  244
# 245   0.002  245
# 246   0.002  246
# 247   0.002  247
# 248   0.002  248
# 249   0.002  249
# 250   0.002  250
# 251   0.002  251
# 252   0.002  252
# 253   0.002  253
# 254   0.002  254
# 255   0.002  255
# 256   0.003  256
# 257   0.003  257
# 258   0.003  258
# 259   0.003  259
# 260   0.003  260
# 261   0.003  261
# 262   0.003  262
# 263   0.003  263
# 264   0.003  264
# 265   0.003  265
# 266   0.003  266
# 267   0.003  267
# 268   0.003  268
# 269   0.003  269
# 270   0.003  270
# 271   0.003  271
# 272   0.003  272
# 273   0.003  273
# 274   0.003  274
# 275   0.003  275
# 276   0.003  276
# 277   0.003  277
# 278   0.003  278
# 279   0.003  279
# 280   0.003  280
# 281   0.003  281
# 282   0.003  282
# 283   0.003  283
# 284   0.003  284
# 285   0.003  285
# 286   0.003  286
# 287  60.002  287
# 288  60.002  288
# 289  60.002  289
# 290  60.002  290
# ...
